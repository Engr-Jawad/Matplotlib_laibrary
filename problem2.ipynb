# %% [markdown]
# # Student Marks Analysis
#
# You have the marks of 10 students in 3 subjects: Math, Science, and English.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

marks = np.array([
    [78, 85, 90],
    [65, 70, 75],
    [88, 92, 95],
    [55, 60, 58],
    [72, 75, 80],
    [90, 95, 98],
    [68, 72, 70],
    [82, 85, 88],
    [77, 80, 83],
    [60, 65, 68]
])

# %%
df = pd.DataFrame(marks,columns=["science","maths","english"])
students = [f"students_{i}"for i in range(1,11)]
df["students"] = students
df
print("display first five rows : ", df.head(5))
print("\n\n")
print("display last three rows : ",df.tail(3))
print("\n\n")
# calculate average marks in each subjects
avg_marks = df[["science", "maths", "english"]].mean()
print("average marks in each subjects : ", avg_marks)
print("\n\n")
# add new columns total 
df["Total"] = df["science"] + df["maths"] + df["english"]
# add new columns average 
df["average"] =  df[["science", "maths", "english"]].mean(axis=1)

# find students with highest total marks
student_high_marks = df.loc[df["Total"].idxmax()]
print("students with highest marks :\n ",student_high_marks)
print("\n\n")
# find students with lowest total marks 
student_lowest_marks = df.loc[df["Total"].idxmin()]
print("student with lowest marks : \n",student_lowest_marks)
# summary statistics
df.describe()
# Out:
# display first five rows :     science  maths  english    students
# 0       78     85       90  students_1
# 1       65     70       75  students_2
# 2       88     92       95  students_3
# 3       55     60       58  students_4
# 4       72     75       80  students_5
#
#
#
# display last three rows :     science  maths  english     students
# 7       82     85       88   students_8
# 8       77     80       83   students_9
# 9       60     65       68  students_10
#
#
#
# average marks in each subjects :  science    73.5
# maths      77.9
# english    80.5
# dtype: float64
#
#
#
# students with highest marks :
#   science             90
# maths               95
# english             98
# students    students_6
# Total              283
# average      94.333333
# Name: 5, dtype: object
#
#
#
# student with lowest marks :
#  science             55
# maths               60
# english             58
# students    students_4
# Total              173
# average      57.666667
# Name: 3, dtype: object
#         science      maths    english      Total    average
# count  10.00000  10.000000  10.000000   10.00000  10.000000
# mean   73.50000  77.900000  80.500000  231.90000  77.300000
# std    11.62612  11.493476  12.791056   35.71321  11.904403
# min    55.00000  60.000000  58.000000  173.00000  57.666667
# 25%    65.75000  70.500000  71.250000  210.00000  70.000000
# 50%    74.50000  77.500000  81.500000  233.50000  77.833333
# 75%    81.00000  85.000000  89.500000  254.50000  84.833333
# max    90.00000  95.000000  98.000000  283.00000  94.333333
